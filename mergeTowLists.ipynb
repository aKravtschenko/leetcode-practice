# %% [markdown]
# You are given the heads of two sorted linked lists list1 and list2.
#
# Merge the two lists into one sorted list. The list should be made by splicing together the nodes of the first two lists.
#
# Return the head of the merged linked list.
#
# Input: list1 = [1,2,4], list2 = [1,3,4]
# Output: [1,1,2,3,4,4]
#
# Example 2:
#
# Input: list1 = [], list2 = []
# Output: []
#
# Example 3:
#
# Input: list1 = [], list2 = [0]
# Output: [0]

# %%
list1 = [-1, 1,2,4]
list2 = [1,3,4]
# Output: [1,1,2,3,4,4]

# %%
list1 += list2

# %%
list1.sort()
list1
# Out:
# [-1, 1, 1, 2, 3, 4, 4]

# %%
sorted = []
sorted = list1 + list2 

sorted.sort()
sorted
# Out:
# [-1, 1, 1, 2, 3, 4, 4]

# %%
list1 = [1, 2, 3]
list2 = [1,2]
# Output: [1,1,2,3,4,4]
# Definition for singly-linked list.
class ListNode(object):
     def __init__(self, val=0, next=None):
         self.val = val
         self.next = next
         
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        if list1.val or list2.val == None:
            return list1.val
        else:
            list1.val += list2.val
        #list1.val.sort()
            return list1.val.sort()

result = Solution.mergeTwoLists(None, ListNode(list1), ListNode(list2))
print(result)
# Out:
# [1, 2, 3]

# %%
l1 = ListNode(1,ListNode(2, ListNode(3, None)))

# %%
l1.val
# Out:
# 1

# %%
def print_llist(head):
    curr = head

    while curr:
        if not curr.next:
            print(curr.val)
        else:
            print(curr.val, end=" --> ")
        curr = curr.next

# %%
l1 = l1 = ListNode(1,ListNode(2, ListNode(3, None)))
l2 = l2 = ListNode(1,ListNode(2, ListNode(4, ListNode(5, None))))

dummy = temp = ListNode(0)
while l1 != None and l2 != None:
    if l1.val < l2.val: #2
        temp.next = l1 #3
        l1 = l1.next #4
    else: 
        temp.next = l2
        l2 = l2.next
    temp = temp.next
temp.next = l1 or l2  #5

# %%
print_llist(dummy)
# Out:
# 0 --> 1 --> 1 --> 2 --> 2 --> 3 --> 4 --> 5

# %%
dummy.next.next.next.next.next.next.val
# Out:
# 4

# %%
list1.val.sort()
list1.val
# Out:
# [-1, 1, 1, 2, 3, 4, 4]

# %%
# Definition for singly-linked list.
class ListNode(object):
     def __init__(self, val=0, next=None):
         self.val = val
         self.next = next
         
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        sorted = []
        sorted = list1 + list2 
        sorted.sort()
        return sorted

result = Solution.mergeTwoLists(None, list1, list2)
print(result)
