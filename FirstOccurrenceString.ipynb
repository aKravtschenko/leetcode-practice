# %% [markdown]
# Find the Index of the First Occurrence in a String
#
# Given two strings needle and haystack, return the index of the first occurrence of needle in haystack, or -1 if needle is not part of haystack.
#
# Example 1:
#
# Input: haystack = "sadbutsad", needle = "sad"
# Output: 0
# Explanation: "sad" occurs at index 0 and 6.
# The first occurrence is at index 0, so we return 0.
#
# Example 2:
#
# Input: haystack = "leetcode", needle = "leeto"
# Output: -1
# Explanation: "leeto" did not occur in "leetcode", so we return -1.

# %%
haystack = "testtesto"
needle = "testo"

# %%
if "sad" in haystack:
    print(haystack)

# %%
haystack = "mississippi"
needle = "issip"

# %%
haystack = "bbbbababbbaabbba"
needle = "abb"

# %%
haystack[4-1] == needle[0]
# Out:
# False

# %%
i = 0
j = 0
if needle in haystack:
    while i <= len(haystack):  
        if j == len(needle):
            print("Index =", i - len(needle))
            break

        if haystack[i] == needle[j]:
            print(haystack[i], "index:", i)
            j += 1
            i += 1
        else:
           
            i = i - j + 1
            j = 0
else:
    print("-1")
# Out:
# i index: 1
# s index: 2
# s index: 3
# i index: 4
# i index: 4
# s index: 5
# s index: 6
# i index: 7
# p index: 8
# Index = 4

# %%
i = 0
j = 0
count = 0
while i <= len(haystack):
    if needle in haystack:
        if j != len(needle):
            if haystack[i] == needle[j]:
                print(haystack[i], "index:",i)
                j+=1
            elif haystack[i] == needle[0]:
                i-=1
                j = 0
            else:
                j= 0
            i+=1
        else:
            print("Index =", (i - len(needle)))
            break
    else:
        print("-1")
        break
# Out:
# t index: 0
# e index: 1
# s index: 2
# t index: 3
# t index: 4
# e index: 5
# s index: 6
# t index: 7
# o index: 8
# Index = 4

# %%
i = 0
j = 0
while i < len(haystack) and j != len(needle):
    if j != len(needle):
        if haystack[i] == needle[j]:
            print(haystack[i], "index:",i)
            j+=1
        else:
            j = 0
        i+=1
    else:
        print("Index =", (i - len(needle)))
        break
# Out:
# l index: 2
# l index: 3

# %%
class Solution(object):
    def strStr(self, haystack, needle):
        """
        :type haystack: str
        :type needle: str
        :rtype: int
        """
        i = 0
        j = 0
        if needle in haystack:
            while i <= len(haystack):
                if j != len(needle):
                    if haystack[i] == needle[j]:
                        #print(haystack[i], "index:",i)
                        j+=1
                    elif haystack[i] == needle[j]:
                            i-=1
                            j = 0
                    i+=1
                else:
                    return i - len(needle)
        else:
            return -1

# %%
class Solution(object):
    def strStr(self, haystack, needle):
        """
        :type haystack: str
        :type needle: str
        :rtype: int
        """
        i = 0
        j = 0
        if needle in haystack:
            while i <= len(haystack):  
                if j == len(needle):
                    return i - len(needle)
                if haystack[i] == needle[j]:
                    j += 1
                    i += 1
                else:
                    i = i - j + 1 
                    j = 0
        else:
            return -1
# i = i - j + 1  -> Start vom neuen Kandidaten, da wir j Schritte zurück gehen müssen und +1 damit es weiter zählt

# %%
haystack = "testtesto1"
needle = "testo"

# %%
haystack = "hello"
needle = "ll"

# %%
haystack = "mississippi"
needle = "issip"

# %%
Solution.strStr(None, haystack, needle)
# Out:
# 6
