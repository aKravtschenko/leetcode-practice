# %% [markdown]
# Given the head of a sorted linked list, delete all duplicates such that each element appears only once. Return the linked list sorted as well.
#
# Example 1:
#
# Input: head = [1,1,2]
# Output: [1,2]
#
# Example 2:
#
# Input: head = [1,1,2,3,3]
# Output: [1,2,3]

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution(object):
    def deleteDuplicates(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

# %%
def print_llist(root):
    curr = root

    while curr:
        if not curr.next:
            print(curr.val)
        else:
            print(curr.val, end=" --> ")
        curr = curr.next

# %%
dummy = ListNode(1,ListNode(1, ListNode(2, ListNode(3, None))))
print_llist(dummy)
# Out:
# 1 --> 1 --> 2 --> 3

# %%
# Out:
# 1 --> 1 --> 2 --> 3

# %%
next_val = ListNode(0, None)

print_llist(next_val)
# Out:
# 0

# %%
list = ListNode(1,ListNode(1, ListNode(2, ListNode(3, None))))
print_llist(list)
# Out:
# 1 --> 1 --> 2 --> 3

# %%
list = ListNode(1,ListNode(1, ListNode(2, ListNode(3, None))))

count = 0
cur = list
dummy = next_val = temp = ListNode(0, None)
while cur != None:
    if next_val.val != cur.val:
        next_val = next_val.next
        if not cur.next:
            print(cur.val, " Ola Not")
        else:
            next_val.next = cur
            print(next_val.val)
    else:
        next_val.next = cur
        print("prev_val.next", next_val.val)
        cur = cur.next

    count+=1
    cur = cur.next

print_llist(dummy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[267], line 12
#      10         print(cur.val, " Ola Not")
#      11     else:
# ---> 12         next_val.next = cur
#      13         print(next_val.val)
#      14 else:
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %%
l1 = l1 = ListNode(1,ListNode(2, ListNode(3, None)))
l2 = l2 = ListNode(1,ListNode(2, ListNode(4, ListNode(5, None))))

dummy = temp = ListNode(0)
while l1 != None and l2 != None:
    if l1.val < l2.val: #2
        temp.next = l1 #3
        l1 = l1.next #4
    else: 
        temp.next = l2
        l2 = l2.next
    temp = temp.next
temp.next = l1 or l2  #5

# %%
print_llist(dummy)
# Out:
# 0 --> 1 --> 1 --> 2 --> 2 --> 3 --> 4 --> 5
