# %% [markdown]
# Given a sorted array of distinct integers and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# You must write an algorithm with O(log n) runtime complexity.
#
# Example 1:
#
# Input: nums = [1,3,5,6], target = 5
# Output: 2
#
# Example 2:
#
# Input: nums = [1,3,5,6], target = 2
# Output: 1
#
# Example 3:
#
# Input: nums = [1,3,5,6], target = 7
# Output: 4

# %%
nums = [1,3,5,6]
nums_set = {}
target = 2

nums_set = set(nums)
nums_set.add(target)
nums_set
# Out:
# {1, 2, 3, 5, 6}

# %%
nums = [1001]
target = 2

new_set = set(nums)
new_set.add(target)
new_set
# Out:
# {2, 1001}

# %%
try:
    nums.index(target)
    print(nums.index(target))
except ValueError as e:
    nums_set = set(nums)
    nums_set.add(target)
    for i,j in enumerate(nums_set):
        if j == target:
            break
    print("index: ", i)
    print(target in nums_set)
    print(nums_set)
# Out:
# index:  1
# True
# {1001, 2}

# %%
class Solution(object):
    def searchInsert(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: int
        """
        try:
            return nums.index(target)
        except ValueError:
            new_set = set(nums)
            new_set.add(target)
            for i,j in enumerate(sorted(new_set)):
                if j == target:
                    return i

# %%
nums = [1,3,5,6]
target = 2

new_set = set(nums)
new_set.add(target)
new_set
# Out:
# {1, 2, 3, 5, 6}

# %%
nums = [1,3,5,6]
target = 2

value = Solution.searchInsert(None, nums, target)
print(value)
# Out:
# 0 1
# 1 2
# 1
